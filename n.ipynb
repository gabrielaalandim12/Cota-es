# %%
from pandas_datareader import data as web
import pandas as pd
import matplotlib.pyplot as plt

cotacao_bovespa = web.DataReader('^BVSP' , data_source ='yahoo' , start="01/01/2019" , end="01/01/2022")
display(cotacao_bovespa)
cotacao_bovespa["Adj Close"]. plot(figsize=(18, 11))
plt.show()
# Out:
#               High     Low    Open   Close    Volume  Adj Close
# Date
# 2019-01-02   91479   87536   87887   91012   5615400      91012
# 2019-01-03   91596   89922   91011   91564   6066200      91564
# 2019-01-04   92701   90824   91577   91841   5322100      91841
# 2019-01-07   92552   91288   91845   91699   4565000      91699
# 2019-01-08   92231   91064   91699   92032   4496500      92032
# ...            ...     ...     ...     ...       ...        ...
# 2021-12-23  105453  104637  105251  104891   7283600     104891
# 2021-12-27  105694  104798  104892  105531   7594900     105531
# 2021-12-28  105652  104503  105555  104864   7509000     104864
# 2021-12-29  105190  103851  104863  104107   6590000     104107
# 2021-12-30  105269  104106  104106  104822  11138100     104822
#
# [743 rows x 6 columns]

# %%
tabela_empresas = pd.read_excel("Empresas.xlsx")
display(tabela_empresas)

for empresa in tabela_empresas['Empresas']:
    print(empresa)
    cotacao = web.DataReader(f'{empresa}.SA' , data_source ='yahoo' , start="01/01/2019" , end="01/01/2022")
    display(cotacao)
    cotacao["Adj Close"]. plot(figsize=(18, 11))
    plt.show()
# Out:
#   Empresas
# 0    ITUB4
# 1    PETR4
# 2    BBDC4
# 3    VALE3
# ITUB4
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2019-01-02  37.139999  35.349998  35.439999  37.000000  25581700.0  32.519539
# 2019-01-03  37.610001  36.450001  36.750000  37.610001  21938600.0  33.055664
# 2019-01-04  37.709999  36.750000  37.220001  36.980000  24873500.0  32.501968
# 2019-01-07  37.500000  36.750000  36.799999  37.049999  16901100.0  32.563499
# 2019-01-08  37.570000  36.560001  37.180000  37.520000  19556300.0  32.976582
# ...               ...        ...        ...        ...         ...        ...
# 2021-12-23  21.570000  21.170000  21.330000  21.340000  22377000.0  20.937693
# 2021-12-27  21.700001  21.309999  21.480000  21.559999  14025800.0  21.153545
# 2021-12-28  21.700001  21.400000  21.629999  21.480000  15294200.0  21.075054
# 2021-12-29  21.580000  21.230000  21.530001  21.299999  12856100.0  20.898451
# ...
